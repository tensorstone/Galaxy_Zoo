# %%
import pandas as pd
import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt  
from scipy.stats import norm  
import keras
from keras.models import Sequential
from keras.initializers import VarianceScaling,RandomNormal
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D
from keras.layers import UpSampling2D, Reshape, Lambda, Flatten, Activation
from keras.models import Model  
from keras.optimizers import SGD, Adadelta, Adagrad,Adam
from keras import backend as K  
from keras import objectives  
from keras.utils.vis_utils import plot_model  
from keras.utils import np_utils, generic_utils
import sys 
import tensorflow as tf
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.layers.normalization import BatchNormalization
import matplotlib.pyplot as plt
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import sklearn
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
from sklearn import manifold, datasets
from sklearn.utils import check_random_state
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
path = os.listdir('cstor/xsede/users/xs-haosun/SDSS_2000/')
#pick up the 1st image to have a look   
path_now = path[0]
a = np.load('cstor/xsede/users/xs-haosun/SDSS_2000/'+str(path_now))
Obj_ID = []
Image = []
Class = []
Redshift = []
for i in range(len(path)):
    path_now = path[i]
    a = np.load('cstor/xsede/users/xs-haosun/SDSS_2000/'+str(path_now))
    for j in range(a.shape[0]):
        Obj_ID.append(a[j]['objID'])
        Image.append(a[j]['image'])
        Class.append(a[j]['class'])
        Redshift.append(a[j]['z'])
Obj_ID = np.asarray(Obj_ID)
Image = np.asarray(Image)
Class = np.asarray(Class)
Redshift = np.asarray(Redshift)
Class[Class=='STAR'] = 0
Class[Class=='GALAXY'] = 1
Class[Class=='QSO'] = 2
Class = Class.astype(int)

Image_RGB = np.empty((len(Image),64,64,3))#(14142,64,64,3) RGB images
for i in range(len(Image)):
    #b[i] = np.stack((a[i][1][0],a[i][1][1],a[i][1][2],a[i][1][3],a[i][1][4]),axis=-1)
    Image_RGB[i] = np.stack((Image[i][3],Image[i][2],Image[i][1]),axis=-1)


for i in range(len(Image_RGB)):
    if True in np.isnan(Image_RGB[i]).reshape(64*64*3):
        print(i)
        Image_RGB[i][np.isnan(Image_RGB[i])==True]=np.mean(Image_RGB[i-1])
        
Image_RGB -= np.mean(Image_RGB)
Image_RGB /= np.max(Image_RGB)
# Out:
# 815

# %%
label = np_utils.to_categorical(Class, 3)
data = Image_RGB
index = [i for i in range(len(data))]
#random.shuffle(index)
train_data = data[index]
train_label = label[index]
Class = Class[index]
Redshift = Redshift[index]
print('train_data.shape:',train_data.shape)
print('train_label.shape:',train_label.shape)
# Out:
# train_data.shape: (14142, 64, 64, 3)
# train_label.shape: (14142, 3)

# %%
batch_size =100
latent_dim = 2
nb_epoch = 50  
epsilon_std = 0.1
intermediate_dim =256
original_dim = 64*64
LRelu = keras.layers.advanced_activations.LeakyReLU(alpha=0.3)
#USE = 'autoencoder'
USE = 'vae'
#encoder:
input_img = Input(shape=(64,64,3))


x = Conv2D(40, (3, 3),padding='same',kernel_initializer='normal')(input_img)
x = BatchNormalization()(x)
x = Activation(LRelu)(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(40, (3, 3), padding='same',kernel_initializer='normal')(x)
x = BatchNormalization()(x)
x = Activation(LRelu)(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal')(x)
x = BatchNormalization()(x)
x = Activation(LRelu)(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal')(x)
x = BatchNormalization()(x)
x = Activation(LRelu)(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal')(x)
x = BatchNormalization()(x)
x = Activation(LRelu)(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(x)
h_1 = Dense(intermediate_dim, activation='tanh')(visual)

z_mean = Dense(latent_dim)(h_1)
#z_mean = Dense(latent_dim,activation='tanh')(h_1)
z_log_var = Dense(latent_dim)(h_1)

def sampling(args):
    z_mean, z_log_var = args  
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2)* epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

if USE == 'vae':
    h_3 = Dense(intermediate_dim,activation='tanh')(z)#for VAE

    
h_4 = Dense(20*2*2,activation=LRelu)(h_3)
h_5 = Reshape((2,2,20))(h_4)


x = Conv2D(20, (3, 3), activation=LRelu, padding='same',kernel_initializer='normal')(h_5)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation=LRelu, padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation=LRelu, padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(40, (3, 3), activation=LRelu, padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(80,  (3, 3), activation='tanh',padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='tanh', padding='same')(x)

EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
checkpoint = keras.callbacks.ModelCheckpoint('model_save_classification_BN.h5',monitor = 'val_loss',verbose = 1,save_best_only = True)

def vae_loss(x, decoded):  
    xent_loss = K.sum(K.sum(objectives.mse(x ,decoded),axis=-1),axis=-1)
    kl_loss = - 0.5 * K.sum(1 + z_log_var - 0.5*K.square(z_mean-10) - 0.5*K.square(z_mean+10) - K.exp(z_log_var), axis=-1) 
    return 1*xent_loss + 10*kl_loss 

def ae_loss(x, decoded):  
    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
    return xent_loss

if USE == 'autoencoder':
    autoencoder = Model(inputs=input_img, outputs=decoded)
    autoencoder.compile(optimizer='rmsprop', loss=ae_loss)
if USE == 'vae':
    vae = Model(inputs=input_img, outputs=decoded) 
    vae.compile(optimizer='rmsprop', loss=vae_loss)

# %%
vae.fit(train_data[:12000], train_data[:12000],
        shuffle=True,
        epochs=nb_epoch,
        batch_size=batch_size,
        validation_data=(train_data[12000:14100],train_data[12000:14100]),callbacks=[EarlyStopping])
# Out:
# Train on 12000 samples, validate on 2100 samples
# Epoch 1/50
# 12000/12000 [==============================] - 30s - loss: 1241.5685 - val_loss: 1199.0187
# Epoch 2/50
# 12000/12000 [==============================] - 27s - loss: 1186.1251 - val_loss: 1207.0142
# Epoch 3/50
# 12000/12000 [==============================] - 27s - loss: 1176.7748 - val_loss: 1182.5676
# Epoch 4/50
# 12000/12000 [==============================] - 27s - loss: 1174.2688 - val_loss: 1185.0320
# Epoch 5/50
# 12000/12000 [==============================] - 27s - loss: 1171.8168 - val_loss: 1182.8849
# Epoch 6/50
# 12000/12000 [==============================] - 27s - loss: 1170.7777 - val_loss: 1182.8892
# Epoch 7/50
# 12000/12000 [==============================] - 27s - loss: 1169.0939 - val_loss: 1179.9631
# Epoch 8/50
# 12000/12000 [==============================] - 27s - loss: 1168.2073 - val_loss: 1182.7162
# Epoch 9/50
# 12000/12000 [==============================] - 27s - loss: 1167.4098 - val_loss: 1174.6303
# Epoch 10/50
# 12000/12000 [==============================] - 27s - loss: 1166.6822 - val_loss: 1173.8006
# Epoch 11/50
# 12000/12000 [==============================] - 27s - loss: 1165.2367 - val_loss: 1187.6303
# Epoch 12/50
# 12000/12000 [==============================] - 27s - loss: 1165.2061 - val_loss: 1175.9943
# Epoch 13/50
# 12000/12000 [==============================] - 27s - loss: 1164.0202 - val_loss: 1175.7327
# Epoch 14/50
# 12000/12000 [==============================] - 27s - loss: 1163.4821 - val_loss: 1173.5725
# Epoch 15/50
# 12000/12000 [==============================] - 27s - loss: 1163.0746 - val_loss: 1172.6120
# Epoch 16/50
# 12000/12000 [==============================] - 27s - loss: 1161.8325 - val_loss: 1170.2795
# Epoch 17/50
# 12000/12000 [==============================] - 27s - loss: 1162.1935 - val_loss: 1170.4473
# Epoch 18/50
# 12000/12000 [==============================] - 26s - loss: 1161.6201 - val_loss: 1173.6694
# Epoch 19/50
# 12000/12000 [==============================] - 27s - loss: 1161.4237 - val_loss: 1168.0266
# Epoch 20/50
# 12000/12000 [==============================] - 27s - loss: 1160.9278 - val_loss: 1173.0701
# Epoch 21/50
# 12000/12000 [==============================] - 27s - loss: 1160.2105 - val_loss: 1169.9418
# Epoch 22/50
# 12000/12000 [==============================] - 27s - loss: 1159.7843 - val_loss: 1175.3714
# Epoch 23/50
# 12000/12000 [==============================] - 27s - loss: 1159.7789 - val_loss: 1168.2079
# Epoch 24/50
# 12000/12000 [==============================] - 27s - loss: 1159.0982 - val_loss: 1173.1211
# Epoch 25/50
# 12000/12000 [==============================] - 27s - loss: 1159.2176 - val_loss: 1168.5293

# %%
lower_lim = 0
upper_lim = 14100

label_value = np.zeros(len(train_label))
for i in range(len(label_value)):
    label_value[i] =np.argmax(train_label[i])

vis = Model(input_img, z_mean)

# display a 2D plot of the digit classes in the latent space  
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)

x_vis_1 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_1[label_value[lower_lim:upper_lim]<1]=0

x_vis_2 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_2[label_value[lower_lim:upper_lim]==1]=0

plt.figure(figsize=(20, 5))

ax = plt.subplot(1,3,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,2)
plt.scatter( x_vis_1[:, 0] ,x_vis_1[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,3)
plt.scatter( x_vis_2[:, 0] ,x_vis_2[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
lower_lim = 500
upper_lim = 1500


vis = Model(input_img, z_mean)
# display a 2D plot of the digit classes in the latent space
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
n_neighbors = 30
n_components = 1
isomap = manifold.Isomap(n_neighbors, n_components)
hid_pred = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
Y_pred = isomap.fit_transform(hid_pred)


plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
Y_pred = -Y_pred
thr_min = -4
thr_max = 4
test_accuracy = 0.001
test_range = int((thr_max - thr_min)/test_accuracy)
print(test_range)
FP = []
TP = []
TN = []
FN = []
TA = np.ones((Y_pred.shape[0],))
TA[Class[lower_lim:upper_lim] ==0 ] = 0
TA[Class[lower_lim:upper_lim] ==2 ] = 0

for i in range(test_range):
    FP_temp = np.zeros((Y_pred.shape[0]))
    TP_temp = np.zeros((Y_pred.shape[0]))
    TN_temp = np.zeros((Y_pred.shape[0]))
    FN_temp = np.zeros((Y_pred.shape[0]))
    LA = np.zeros((Y_pred.shape[0],))
    thr_now = thr_min+ i*test_accuracy
    LA[Y_pred[:,0] > thr_now] = 1
    for j in range(Y_pred.shape[0]):
        if LA[j]==0:
            if TA[j]==1:
                FN_temp[j] = 1
            else:
                TN_temp[j] = 1
        else:
            if TA[j] == 1:
                TP_temp[j] = 1
            else:
                FP_temp[j] = 1
    FP.append(FP_temp)
    TP.append(TP_temp)
    TN.append(TN_temp)
    FN.append(FN_temp)
    
TPR = np.zeros((test_range,))
FPR = np.zeros((test_range,))
TPR = np.sum(TP,axis=-1)/(np.sum(TP,axis=-1)+np.sum(FN,axis=-1))
FPR = np.sum(FP,axis=-1)/(np.sum(FP,axis=-1)+np.sum(TN,axis=-1))

plt.scatter(FPR,TPR,c=[i for i in range(test_range)])

plt.colorbar()
plt.scatter(FPR[np.argmin((TPR-1)**2 + FPR**2)],TPR[np.argmin((TPR-1)**2 + FPR**2)],c=0,cmap='OrRd_r')
plt.xlabel('FPR')
plt.ylabel('TPR')
#argmax, OrRed

print("AUC:",metrics.auc(FPR, TPR))
# Out:
# 8000
# AUC: 0.709211929721

# %%
lower_lim = 0
upper_lim = 14000


vis = Model(input_img, z_mean)
# display a 2D plot of the digit classes in the latent space
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
n_neighbors = 50
n_components = 1
isomap = manifold.Isomap(n_neighbors, n_components)
hid_pred = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
Y_pred = isomap.fit_transform(hid_pred)


plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
#Y_pred = -Y_pred
thr_min = -4
thr_max = 4
test_accuracy = 0.001
test_range = int((thr_max - thr_min)/test_accuracy)
print(test_range)
FP = []
TP = []
TN = []
FN = []
TA = np.ones((Y_pred.shape[0],))
TA[Class[lower_lim:upper_lim] ==0 ] = 0
TA[Class[lower_lim:upper_lim] ==2 ] = 0

for i in range(test_range):
    FP_temp = np.zeros((Y_pred.shape[0]))
    TP_temp = np.zeros((Y_pred.shape[0]))
    TN_temp = np.zeros((Y_pred.shape[0]))
    FN_temp = np.zeros((Y_pred.shape[0]))
    LA = np.zeros((Y_pred.shape[0],))
    thr_now = thr_min+ i*test_accuracy
    LA[Y_pred[:,0] > thr_now] = 1
    for j in range(Y_pred.shape[0]):
        if LA[j]==0:
            if TA[j]==1:
                FN_temp[j] = 1
            else:
                TN_temp[j] = 1
        else:
            if TA[j] == 1:
                TP_temp[j] = 1
            else:
                FP_temp[j] = 1
    FP.append(FP_temp)
    TP.append(TP_temp)
    TN.append(TN_temp)
    FN.append(FN_temp)
    
TPR = np.zeros((test_range,))
FPR = np.zeros((test_range,))
TPR = np.sum(TP,axis=-1)/(np.sum(TP,axis=-1)+np.sum(FN,axis=-1))
FPR = np.sum(FP,axis=-1)/(np.sum(FP,axis=-1)+np.sum(TN,axis=-1))

plt.scatter(FPR,TPR,c=[i for i in range(test_range)])

plt.colorbar()
plt.scatter(FPR[np.argmin((TPR-1)**2 + FPR**2)],TPR[np.argmin((TPR-1)**2 + FPR**2)],c=0,cmap='OrRd_r')
plt.xlabel('FPR')
plt.ylabel('TPR')
#argmax, OrRed

print("AUC:",metrics.auc(FPR, TPR))
# Out:
# 8000
# AUC: 0.858289450203

# %% [markdown]
# # 1

# %%
batch_size =100
latent_dim = 2
nb_epoch = 50  
epsilon_std = 0.1 
intermediate_dim =256
original_dim = 64*64

#USE = 'autoencoder'
USE = 'vae'
#encoder:

input_img = Input(shape=(64,64,3))


x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(input_img)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(x)
h_1 = Dense(intermediate_dim, activation='tanh')(visual)
encoded = Dense(latent_dim, activation='relu')(h_1)

#z_mean = Dense(latent_dim)(h_1)
z_mean = Dense(latent_dim,activation='tanh')(h_1)
z_log_var = Dense(latent_dim)(h_1)

def sampling(args):   
    z_mean, z_log_var = args  
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2)* epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

if USE == 'vae':
    h_3 = Dense(intermediate_dim,activation='tanh')(z)#for VAE

if USE == 'autoencoder':
    h_3 = Dense(intermediate_dim,activation='tanh')(encoded)#for AE
    
    
h_4 = Dense(20*2*2,activation='relu')(h_3)
h_5 = Reshape((2,2,20))(h_4)


x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(80,  (3, 3), activation='tanh',padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='tanh', padding='same')(x)

EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
checkpoint = keras.callbacks.ModelCheckpoint('model_save_classification_BN.h5',monitor = 'val_loss',verbose = 1,save_best_only = True)


def vae_loss(x, decoded):  
    xent_loss = K.sum(K.sum(objectives.binary_crossentropy(x ,decoded),axis=-1),axis=-1)
    kl_loss_1 = -K.sum(K.square(0 - (z_mean[0])), axis=-1)
    kl_loss_2 = K.sum(K.abs(1- K.exp(z_log_var)), axis=-1)
    return 1*xent_loss + 0.5*kl_loss_1 + 1*kl_loss_2  

def ae_loss(x, decoded):  
    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
    return xent_loss

if USE == 'autoencoder':
    autoencoder = Model(inputs=input_img, outputs=decoded)
    autoencoder.compile(optimizer='rmsprop', loss=ae_loss)
if USE == 'vae':
    vae = Model(inputs=input_img, outputs=decoded) 
    vae.compile(optimizer='rmsprop', loss=vae_loss)

# %%
vae.fit(train_data[:12000], train_data[:12000],
        shuffle=True,
        epochs=nb_epoch,
        batch_size=batch_size,  
        validation_data=(train_data[12000:14100],train_data[12000:14100]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 12000 samples, validate on 2100 samples
# Epoch 1/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7432.7302Epoch 00000: val_loss improved from inf to -7881.38414, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 23s - loss: -7434.7491 - val_loss: -7881.3841
# Epoch 2/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7909.6132Epoch 00001: val_loss improved from -7881.38414 to -7977.93941, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -7905.6583 - val_loss: -7977.9394
# Epoch 3/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7957.2905Epoch 00002: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -7961.3111 - val_loss: -7941.7705
# Epoch 4/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8002.4801Epoch 00003: val_loss improved from -7977.93941 to -7983.30218, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -8000.7886 - val_loss: -7983.3022
# Epoch 5/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7993.2136Epoch 00004: val_loss improved from -7983.30218 to -7999.97677, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -7996.5922 - val_loss: -7999.9768
# Epoch 6/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8009.0895Epoch 00005: val_loss improved from -7999.97677 to -8000.72305, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -8014.1149 - val_loss: -8000.7231
# Epoch 7/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8002.6553Epoch 00006: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8010.2258 - val_loss: -7744.7726
# Epoch 8/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8029.6345Epoch 00007: val_loss improved from -8000.72305 to -8011.14207, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -8025.1172 - val_loss: -8011.1421
# Epoch 9/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8028.3321Epoch 00008: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8032.3007 - val_loss: -8000.9152
# Epoch 10/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8038.1818Epoch 00009: val_loss improved from -8011.14207 to -8019.57615, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8036.4817 - val_loss: -8019.5761
# Epoch 11/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8043.9602Epoch 00010: val_loss improved from -8019.57615 to -8030.37312, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -8044.5107 - val_loss: -8030.3731
# Epoch 12/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8045.0725Epoch 00011: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8043.5567 - val_loss: -7962.1213
# Epoch 13/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8051.8032Epoch 00012: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8047.7381 - val_loss: -8020.2634
# Epoch 14/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8029.3808Epoch 00013: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8039.0122 - val_loss: -7984.7126
# Epoch 15/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8043.1372Epoch 00014: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8040.8619 - val_loss: -7995.5386
# Epoch 16/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8043.1778Epoch 00015: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8041.6799 - val_loss: -8017.8167
# Epoch 17/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8050.6113Epoch 00016: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8055.0802 - val_loss: -8021.7952
# Epoch 18/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8043.1687Epoch 00017: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8045.6287 - val_loss: -7942.1037
# Epoch 19/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8056.9686Epoch 00018: val_loss improved from -8030.37312 to -8031.15709, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8055.7415 - val_loss: -8031.1571
# Epoch 20/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8056.3177Epoch 00019: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8055.8587 - val_loss: -8020.5476
# Epoch 21/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8037.1974Epoch 00020: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8038.2955 - val_loss: -7996.1397
# Epoch 22/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8044.0824Epoch 00021: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8058.2764 - val_loss: -8026.5352
# Epoch 23/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8065.3503Epoch 00022: val_loss improved from -8031.15709 to -8031.45529, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8062.4584 - val_loss: -8031.4553
# Epoch 24/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8044.8484Epoch 00023: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8049.3448 - val_loss: -8027.8597
# Epoch 25/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8050.1001Epoch 00024: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8055.2918 - val_loss: -8031.2207
# Epoch 26/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8058.9061Epoch 00025: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8062.0598 - val_loss: -8025.8919
# Epoch 27/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8054.8491Epoch 00026: val_loss improved from -8031.45529 to -8040.17755, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -8056.2939 - val_loss: -8040.1775
# Epoch 28/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8070.5762- ETEpoch 00027: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8066.9184 - val_loss: -8026.2716
# Epoch 29/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8068.7061Epoch 00028: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8066.6049 - val_loss: -8033.0435
# Epoch 30/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8062.6217Epoch 00029: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8063.5041 - val_loss: -8036.6929
# Epoch 31/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8053.8216Epoch 00030: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8059.9321 - val_loss: -8010.0375
# Epoch 32/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8066.6604Epoch 00031: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8066.4105 - val_loss: -7995.7540
# Epoch 33/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8068.5458Epoch 00032: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8064.3939 - val_loss: -8031.7681
# Epoch 34/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8070.0017Epoch 00033: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8068.6338 - val_loss: -8036.3589
# Epoch 35/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8065.2819Epoch 00034: val_loss improved from -8040.17755 to -8043.68583, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8070.9226 - val_loss: -8043.6858
# Epoch 36/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8070.5684Epoch 00035: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8065.3969 - val_loss: -8041.9915
# Epoch 37/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8073.8366Epoch 00036: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8066.4494 - val_loss: -8029.2452
# Epoch 38/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8063.1817Epoch 00037: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8060.0892 - val_loss: -8026.2448
# Epoch 39/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8070.8221Epoch 00038: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8070.8082 - val_loss: -8015.8182
# Epoch 40/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8061.3207Epoch 00039: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8063.1824 - val_loss: -8036.0458
# Epoch 41/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8064.4551Epoch 00040: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8064.9868 - val_loss: -8043.3526
# Epoch 42/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8071.6736Epoch 00041: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8076.2260 - val_loss: -7990.7728
# Epoch 43/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8061.3598Epoch 00042: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8064.7896 - val_loss: -8028.8626

# %%
vae.load_weights("model_save_classification_BN.h5")

# %%
lower_lim = 0
upper_lim = 14000

label_value = np.zeros(len(train_label))
for i in range(len(label_value)):
    label_value[i] =np.argmax(train_label[i])

vis = Model(input_img, z_mean)

# display a 2D plot of the digit classes in the latent space  
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)

x_vis_1 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_1[label_value[lower_lim:upper_lim]<1]=0

x_vis_2 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_2[label_value[lower_lim:upper_lim]==1]=0

plt.figure(figsize=(20, 5))

ax = plt.subplot(1,3,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,2)
plt.scatter( x_vis_1[:, 0] ,x_vis_1[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,3)
plt.scatter( x_vis_2[:, 0] ,x_vis_2[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
lower_lim = 0
upper_lim = 14000


vis = Model(input_img, z_mean)
# display a 2D plot of the digit classes in the latent space
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
n_neighbors = 50
n_components = 1
isomap = manifold.Isomap(n_neighbors, n_components)
hid_pred = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
Y_pred = isomap.fit_transform(hid_pred)


plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1) 
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
Y_pred = -Y_pred
thr_min = -4
thr_max = 4
test_accuracy = 0.001
test_range = int((thr_max - thr_min)/test_accuracy)
print(test_range)
FP = []
TP = []
TN = []
FN = []
TA = np.ones((Y_pred.shape[0],))
TA[Class[lower_lim:upper_lim] ==0 ] = 0
TA[Class[lower_lim:upper_lim] ==2 ] = 0

for i in range(test_range):
    FP_temp = np.zeros((Y_pred.shape[0]))
    TP_temp = np.zeros((Y_pred.shape[0]))
    TN_temp = np.zeros((Y_pred.shape[0]))
    FN_temp = np.zeros((Y_pred.shape[0]))
    LA = np.zeros((Y_pred.shape[0],))
    thr_now = thr_min+ i*test_accuracy
    LA[Y_pred[:,0] > thr_now] = 1
    for j in range(Y_pred.shape[0]):
        if LA[j]==0:
            if TA[j]==1:
                FN_temp[j] = 1
            else:
                TN_temp[j] = 1
        else:
            if TA[j] == 1:
                TP_temp[j] = 1
            else:
                FP_temp[j] = 1
    FP.append(FP_temp)
    TP.append(TP_temp)
    TN.append(TN_temp)
    FN.append(FN_temp)
    
TPR = np.zeros((test_range,))
FPR = np.zeros((test_range,))
TPR = np.sum(TP,axis=-1)/(np.sum(TP,axis=-1)+np.sum(FN,axis=-1))
FPR = np.sum(FP,axis=-1)/(np.sum(FP,axis=-1)+np.sum(TN,axis=-1))

plt.scatter(FPR,TPR,c=[i for i in range(test_range)])

plt.colorbar()
plt.scatter(FPR[np.argmin((TPR-1)**2 + FPR**2)],TPR[np.argmin((TPR-1)**2 + FPR**2)],c=0,cmap='OrRd_r')
plt.xlabel('FPR')
plt.ylabel('TPR')
#argmax, OrRed

print("AUC:",metrics.auc(FPR, TPR))
# Out:
# 8000
# AUC: 0.874056800995

# %% [markdown]
# # 2

# %%
batch_size =100
latent_dim = 2
nb_epoch = 50  
epsilon_std = 0.1 
intermediate_dim =256
original_dim = 64*64

#USE = 'autoencoder'
USE = 'vae'
#encoder:

input_img = Input(shape=(64,64,3))


x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(input_img)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(x)
h_1 = Dense(intermediate_dim, activation='tanh')(visual)
encoded = Dense(latent_dim, activation='relu')(h_1)

#z_mean = Dense(latent_dim)(h_1)
z_mean = Dense(latent_dim,activation='tanh')(h_1)
z_log_var = Dense(latent_dim)(h_1)

def sampling(args):   
    z_mean, z_log_var = args  
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2)* epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

if USE == 'vae':
    h_3 = Dense(intermediate_dim,activation='tanh')(z)#for VAE

if USE == 'autoencoder':
    h_3 = Dense(intermediate_dim,activation='tanh')(encoded)#for AE
    
    
h_4 = Dense(20*2*2,activation='relu')(h_3)
h_5 = Reshape((2,2,20))(h_4)


x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(80,  (3, 3), activation='tanh',padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='tanh', padding='same')(x)

EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
checkpoint = keras.callbacks.ModelCheckpoint('model_save_classification_BN.h5',monitor = 'val_loss',verbose = 1,save_best_only = True)


def vae_loss(x, decoded):  
    xent_loss = K.sum(K.sum(objectives.binary_crossentropy(x ,decoded),axis=-1),axis=-1)
    kl_loss_1 = -K.sum(K.square(0 - (z_mean[0])), axis=-1)
    kl_loss_2 = K.sum(K.abs(1- K.exp(z_log_var)), axis=-1)
    return 1*xent_loss + 0.5*kl_loss_1 + 1*kl_loss_2  

def ae_loss(x, decoded):  
    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
    return xent_loss

if USE == 'autoencoder':
    autoencoder = Model(inputs=input_img, outputs=decoded)
    autoencoder.compile(optimizer='rmsprop', loss=ae_loss)
if USE == 'vae':
    vae = Model(inputs=input_img, outputs=decoded) 
    vae.compile(optimizer='rmsprop', loss=vae_loss)

# %%
vae.fit(train_data[:12000], train_data[:12000],
        shuffle=True,
        epochs=nb_epoch,
        batch_size=batch_size,  
        validation_data=(train_data[12000:14100],train_data[12000:14100]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 12000 samples, validate on 2100 samples
# Epoch 1/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7399.9762Epoch 00000: val_loss improved from inf to -7716.98361, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -7400.0868 - val_loss: -7716.9836
# Epoch 2/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7833.6351Epoch 00001: val_loss improved from -7716.98361 to -7957.53169, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: -7835.0683 - val_loss: -7957.5317
# Epoch 3/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7954.8539Epoch 00002: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -7951.2890 - val_loss: -7956.4035
# Epoch 4/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7978.3240Epoch 00003: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -7972.2423 - val_loss: -7718.5121
# Epoch 5/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8001.1253Epoch 00004: val_loss did not improve
# 12000/12000 [==============================] - 22s - loss: -8001.3430 - val_loss: -7946.6779
# Epoch 6/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8011.2853Epoch 00005: val_loss improved from -7957.53169 to -7980.35675, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8007.4610 - val_loss: -7980.3567
# Epoch 7/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8005.0369Epoch 00006: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8011.3563 - val_loss: -7960.1531
# Epoch 8/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8024.1664Epoch 00007: val_loss improved from -7980.35675 to -8004.09689, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8026.7885 - val_loss: -8004.0969
# Epoch 9/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8027.2419Epoch 00008: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8023.7406 - val_loss: -7860.2401
# Epoch 10/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8026.1434Epoch 00009: val_loss improved from -8004.09689 to -8008.43229, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8025.5324 - val_loss: -8008.4323
# Epoch 11/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8032.5030Epoch 00010: val_loss improved from -8008.43229 to -8013.94306, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8037.9778 - val_loss: -8013.9431
# Epoch 12/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8038.0811Epoch 00011: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8035.0747 - val_loss: -7965.5862
# Epoch 13/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8019.1980Epoch 00012: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8018.0659 - val_loss: -7994.5629
# Epoch 14/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8035.0274Epoch 00013: val_loss improved from -8013.94306 to -8021.56341, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: -8033.7520 - val_loss: -8021.5634
# Epoch 15/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8046.6561Epoch 00014: val_loss improved from -8021.56341 to -8021.82550, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: -8045.2986 - val_loss: -8021.8255
# Epoch 16/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8027.5081Epoch 00015: val_loss improved from -8021.82550 to -8029.16216, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: -8024.0007 - val_loss: -8029.1622
# Epoch 17/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8049.0641Epoch 00016: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8044.1338 - val_loss: -7984.8719
# Epoch 18/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8047.3761Epoch 00017: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8049.9228 - val_loss: -8021.7081
# Epoch 19/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8042.8593Epoch 00018: val_loss improved from -8029.16216 to -8029.84452, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: -8042.4995 - val_loss: -8029.8445
# Epoch 20/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8054.9972Epoch 00019: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8052.3280 - val_loss: -7985.4038
# Epoch 21/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8047.6168Epoch 00020: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8048.5834 - val_loss: -8018.9668
# Epoch 22/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8052.3470Epoch 00021: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8048.5211 - val_loss: -8022.0288
# Epoch 23/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8048.1548Epoch 00022: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8046.7235 - val_loss: -8018.3253
# Epoch 24/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8052.3809Epoch 00023: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8052.6891 - val_loss: -8026.5313
# Epoch 25/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8058.1097Epoch 00024: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8051.1837 - val_loss: -7651.5370
# Epoch 26/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8049.0101Epoch 00025: val_loss improved from -8029.84452 to -8033.72291, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8051.8262 - val_loss: -8033.7229
# Epoch 27/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8057.1103Epoch 00026: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8054.9976 - val_loss: -7970.5957
# Epoch 28/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8062.2771Epoch 00027: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8056.0363 - val_loss: -7940.7779
# Epoch 29/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8061.3348Epoch 00028: val_loss improved from -8033.72291 to -8035.59777, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -8062.4463 - val_loss: -8035.5978
# Epoch 30/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8064.8885Epoch 00029: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8059.3526 - val_loss: -8034.9824
# Epoch 31/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8063.1027Epoch 00030: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8058.7019 - val_loss: -8028.7737
# Epoch 32/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8064.8278Epoch 00031: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8065.1541 - val_loss: -7995.2431
# Epoch 33/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8049.6312Epoch 00032: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8050.7872 - val_loss: -7976.0463
# Epoch 34/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8044.6078Epoch 00033: val_loss improved from -8035.59777 to -8038.26837, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: -8040.6987 - val_loss: -8038.2684
# Epoch 35/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8070.1635Epoch 00034: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8071.5093 - val_loss: -8033.6346
# Epoch 36/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8065.6113Epoch 00035: val_loss improved from -8038.26837 to -8040.46303, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8068.9722 - val_loss: -8040.4630
# Epoch 37/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8066.3331Epoch 00036: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8063.9451 - val_loss: -7949.8862
# Epoch 38/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8067.9189Epoch 00037: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8067.8006 - val_loss: -8014.8196
# Epoch 39/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8079.6345Epoch 00038: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8075.3753 - val_loss: -8028.5621
# Epoch 40/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8059.8538Epoch 00039: val_loss improved from -8040.46303 to -8042.06243, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8066.2512 - val_loss: -8042.0624
# Epoch 41/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8066.8105Epoch 00040: val_loss improved from -8042.06243 to -8045.65788, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8071.6990 - val_loss: -8045.6579
# Epoch 42/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8075.0176Epoch 00041: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8072.8295 - val_loss: -8028.6455
# Epoch 43/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8061.6876Epoch 00042: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8058.9945 - val_loss: -8007.0099
# Epoch 44/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8068.2533Epoch 00043: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8072.9314 - val_loss: -8043.4955
# Epoch 45/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8065.2848Epoch 00044: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8061.5334 - val_loss: -8020.0639
# Epoch 46/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8069.8357Epoch 00045: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8069.7585 - val_loss: -8032.9840
# Epoch 47/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8069.9540Epoch 00046: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8071.2396 - val_loss: -8033.7785
# Epoch 48/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8072.9605Epoch 00047: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8068.9630 - val_loss: -8029.1747
# Epoch 49/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8073.4621Epoch 00048: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8076.7178 - val_loss: -8042.4193

# %%
vae.load_weights("model_save_classification_BN.h5")

# %%
lower_lim = 0
upper_lim = 14000

label_value = np.zeros(len(train_label))
for i in range(len(label_value)):
    label_value[i] =np.argmax(train_label[i])

vis = Model(input_img, z_mean)

# display a 2D plot of the digit classes in the latent space  
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)

x_vis_1 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_1[label_value[lower_lim:upper_lim]<1]=0

x_vis_2 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_2[label_value[lower_lim:upper_lim]==1]=0

plt.figure(figsize=(20, 5))

ax = plt.subplot(1,3,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,2)
plt.scatter( x_vis_1[:, 0] ,x_vis_1[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,3)
plt.scatter( x_vis_2[:, 0] ,x_vis_2[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
lower_lim = 0
upper_lim = 14000


vis = Model(input_img, z_mean)
# display a 2D plot of the digit classes in the latent space
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
n_neighbors = 50
n_components = 1
isomap = manifold.Isomap(n_neighbors, n_components)
hid_pred = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
Y_pred = isomap.fit_transform(hid_pred)


plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
#Y_pred = -Y_pred
thr_min = -4
thr_max = 4
test_accuracy = 0.001
test_range = int((thr_max - thr_min)/test_accuracy)
print(test_range)
FP = []
TP = []
TN = []
FN = []
TA = np.ones((Y_pred.shape[0],))
TA[Class[lower_lim:upper_lim] ==0 ] = 0
TA[Class[lower_lim:upper_lim] ==2 ] = 0

for i in range(test_range):
    FP_temp = np.zeros((Y_pred.shape[0]))
    TP_temp = np.zeros((Y_pred.shape[0]))
    TN_temp = np.zeros((Y_pred.shape[0]))
    FN_temp = np.zeros((Y_pred.shape[0]))
    LA = np.zeros((Y_pred.shape[0],))
    thr_now = thr_min+ i*test_accuracy
    LA[Y_pred[:,0] > thr_now] = 1
    for j in range(Y_pred.shape[0]):
        if LA[j]==0:
            if TA[j]==1:
                FN_temp[j] = 1
            else:
                TN_temp[j] = 1
        else:
            if TA[j] == 1:
                TP_temp[j] = 1
            else:
                FP_temp[j] = 1
    FP.append(FP_temp)
    TP.append(TP_temp)
    TN.append(TN_temp)
    FN.append(FN_temp)
    
TPR = np.zeros((test_range,))
FPR = np.zeros((test_range,))
TPR = np.sum(TP,axis=-1)/(np.sum(TP,axis=-1)+np.sum(FN,axis=-1))
FPR = np.sum(FP,axis=-1)/(np.sum(FP,axis=-1)+np.sum(TN,axis=-1))

plt.scatter(FPR,TPR,c=[i for i in range(test_range)])

plt.colorbar()
plt.scatter(FPR[np.argmin((TPR-1)**2 + FPR**2)],TPR[np.argmin((TPR-1)**2 + FPR**2)],c=0,cmap='OrRd_r')
plt.xlabel('FPR')
plt.ylabel('TPR')
#argmax, OrRed

print("AUC:",metrics.auc(FPR, TPR))

# %% [markdown]
# # 3

# %%
batch_size =100
latent_dim = 2
nb_epoch = 50  
epsilon_std = 0.1 
intermediate_dim =512
original_dim = 64*64

#USE = 'autoencoder'
USE = 'vae'
#encoder:

input_img = Input(shape=(64,64,3))


x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(input_img)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(x)
h_1 = Dense(intermediate_dim, activation='tanh')(visual)
encoded = Dense(latent_dim, activation='relu')(h_1)

#z_mean = Dense(latent_dim)(h_1)
z_mean = Dense(latent_dim,activation='tanh')(h_1)
z_log_var = Dense(latent_dim)(h_1)

def sampling(args):   
    z_mean, z_log_var = args  
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2)* epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

if USE == 'vae':
    h_3 = Dense(intermediate_dim,activation='tanh')(z)#for VAE

if USE == 'autoencoder':
    h_3 = Dense(intermediate_dim,activation='tanh')(encoded)#for AE
    
    
h_4 = Dense(20*2*2,activation='relu')(h_3)
h_5 = Reshape((2,2,20))(h_4)


x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(80,  (3, 3), activation='tanh',padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='tanh', padding='same')(x)

EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
checkpoint = keras.callbacks.ModelCheckpoint('model_save_classification_BN.h5',monitor = 'val_loss',verbose = 1,save_best_only = True)


def vae_loss(x, decoded):  
    xent_loss = K.sum(K.sum(objectives.binary_crossentropy(x ,decoded),axis=-1),axis=-1)
    kl_loss_1 = -K.sum(K.square(0 - (z_mean[0])), axis=-1)
    kl_loss_2 = K.sum(K.abs(1- K.exp(z_log_var)), axis=-1)
    return 1*xent_loss + 0.00001*kl_loss_1 + 1*kl_loss_2  

def ae_loss(x, decoded):  
    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
    return xent_loss

if USE == 'autoencoder':
    autoencoder = Model(inputs=input_img, outputs=decoded)
    autoencoder.compile(optimizer='rmsprop', loss=ae_loss)
if USE == 'vae':
    vae = Model(inputs=input_img, outputs=decoded) 
    vae.compile(optimizer='rmsprop', loss=vae_loss)

# %%
vae.fit(train_data[:12000], train_data[:12000],
        shuffle=True,
        epochs=nb_epoch,
        batch_size=batch_size,  
        validation_data=(train_data[12000:14100],train_data[12000:14100]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 12000 samples, validate on 2100 samples
# Epoch 1/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7342.7570Epoch 00000: val_loss improved from inf to -7847.21726, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: -7347.2272 - val_loss: -7847.2173
# Epoch 2/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7889.9618Epoch 00001: val_loss improved from -7847.21726 to -7938.92787, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -7886.8299 - val_loss: -7938.9279
# Epoch 3/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7938.8751Epoch 00002: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -7942.5440 - val_loss: -7537.9506
# Epoch 4/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7975.6903Epoch 00003: val_loss improved from -7938.92787 to -7993.84289, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -7977.3127 - val_loss: -7993.8429
# Epoch 5/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -7960.8574Epoch 00004: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -7971.6588 - val_loss: -7976.2703
# Epoch 6/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8002.3512Epoch 00005: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8001.2104 - val_loss: -7977.3788
# Epoch 7/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8015.3058Epoch 00006: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8015.9795 - val_loss: -7928.9284
# Epoch 8/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8006.3109Epoch 00007: val_loss improved from -7993.84289 to -8015.48335, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8014.5656 - val_loss: -8015.4834
# Epoch 9/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8018.1585Epoch 00008: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8023.1639 - val_loss: -8015.4254
# Epoch 10/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8031.3867Epoch 00009: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8032.1842 - val_loss: -7998.6979
# Epoch 11/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8025.4139Epoch 00010: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8026.8690 - val_loss: -8013.0590
# Epoch 12/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8040.7688Epoch 00011: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8036.4343 - val_loss: -7731.7669
# Epoch 13/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8050.0480Epoch 00012: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8048.7850 - val_loss: -8006.3300
# Epoch 14/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8041.7303Epoch 00013: val_loss improved from -8015.48335 to -8025.69106, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8037.0297 - val_loss: -8025.6911
# Epoch 15/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8045.6067Epoch 00014: val_loss improved from -8025.69106 to -8032.13211, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: -8044.0124 - val_loss: -8032.1321
# Epoch 16/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8019.2862Epoch 00015: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8026.1257 - val_loss: -8023.9790
# Epoch 17/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8022.5870Epoch 00016: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8029.5929 - val_loss: -7964.4705
# Epoch 18/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8052.6034Epoch 00017: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8050.5768 - val_loss: -7989.2553
# Epoch 19/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8037.5356Epoch 00018: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8044.5030 - val_loss: -7989.6304
# Epoch 20/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8050.7784Epoch 00019: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: -8051.8510 - val_loss: -8031.0984
# Epoch 21/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8040.8115Epoch 00020: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8043.1181 - val_loss: -8022.2417
# Epoch 22/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8051.6667Epoch 00021: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8047.5828 - val_loss: -8020.2386
# Epoch 23/50
# 11900/12000 [============================>.] - ETA: 0s - loss: -8053.0969Epoch 00022: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: -8059.1656 - val_loss: -7948.9998

# %%
lower_lim = 0
upper_lim = 14000

label_value = np.zeros(len(train_label))
for i in range(len(label_value)):
    label_value[i] =np.argmax(train_label[i])

vis = Model(input_img, z_mean)

# display a 2D plot of the digit classes in the latent space  
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)

x_vis_1 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_1[label_value[lower_lim:upper_lim]<1]=0

x_vis_2 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_2[label_value[lower_lim:upper_lim]==1]=0

plt.figure(figsize=(20, 5))

ax = plt.subplot(1,3,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,2)
plt.scatter( x_vis_1[:, 0] ,x_vis_1[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,3)
plt.scatter( x_vis_2[:, 0] ,x_vis_2[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
lower_lim = 0
upper_lim = 14000


vis = Model(input_img, z_mean)
# display a 2D plot of the digit classes in the latent space
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
n_neighbors = 50
n_components = 1
isomap = manifold.Isomap(n_neighbors, n_components)
hid_pred = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
Y_pred = isomap.fit_transform(hid_pred)


plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
Y_pred = -Y_pred
thr_min = -4
thr_max = 4
test_accuracy = 0.001
test_range = int((thr_max - thr_min)/test_accuracy)
print(test_range)
FP = []
TP = []
TN = []
FN = []
TA = np.ones((Y_pred.shape[0],))
TA[Class[lower_lim:upper_lim] ==0 ] = 0
TA[Class[lower_lim:upper_lim] ==2 ] = 0

for i in range(test_range):
    FP_temp = np.zeros((Y_pred.shape[0]))
    TP_temp = np.zeros((Y_pred.shape[0]))
    TN_temp = np.zeros((Y_pred.shape[0]))
    FN_temp = np.zeros((Y_pred.shape[0]))
    LA = np.zeros((Y_pred.shape[0],))
    thr_now = thr_min+ i*test_accuracy
    LA[Y_pred[:,0] > thr_now] = 1
    for j in range(Y_pred.shape[0]):
        if LA[j]==0:
            if TA[j]==1:
                FN_temp[j] = 1
            else:
                TN_temp[j] = 1
        else:
            if TA[j] == 1:
                TP_temp[j] = 1
            else:
                FP_temp[j] = 1
    FP.append(FP_temp)
    TP.append(TP_temp)
    TN.append(TN_temp)
    FN.append(FN_temp)
    
TPR = np.zeros((test_range,))
FPR = np.zeros((test_range,))
TPR = np.sum(TP,axis=-1)/(np.sum(TP,axis=-1)+np.sum(FN,axis=-1))
FPR = np.sum(FP,axis=-1)/(np.sum(FP,axis=-1)+np.sum(TN,axis=-1))

plt.scatter(FPR,TPR,c=[i for i in range(test_range)])

plt.colorbar()
plt.scatter(FPR[np.argmin((TPR-1)**2 + FPR**2)],TPR[np.argmin((TPR-1)**2 + FPR**2)],c=0,cmap='OrRd_r')
plt.xlabel('FPR')
plt.ylabel('TPR')
#argmax, OrRed

print("AUC:",metrics.auc(FPR, TPR))
# Out:
# 8000
# AUC: 0.890954309319

# %% [markdown]
# # 4

# %%
batch_size =100
latent_dim = 2
nb_epoch = 50  
epsilon_std = 0.1
intermediate_dim =512
original_dim = 64*64

#USE = 'autoencoder'
USE = 'vae'
#encoder:

input_img = Input(shape=(64,64,3))


x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(input_img)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = MaxPooling2D((2, 2),  padding='same')(x)

#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(x)
h_1 = Dense(intermediate_dim, activation='tanh')(visual)
encoded = Dense(latent_dim, activation='relu')(h_1)

z_mean = Dense(latent_dim)(h_1) #using W_loss
#z_mean = Dense(latent_dim,activation='tanh')(h_1) 
z_log_var = Dense(latent_dim)(h_1)

def sampling(args):   
    z_mean, z_log_var = args  
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2)* epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

if USE == 'vae':
    h_3 = Dense(intermediate_dim,activation='tanh')(z)#for VAE

if USE == 'autoencoder':
    h_3 = Dense(intermediate_dim,activation='tanh')(encoded)#for AE
    
    
h_4 = Dense(20*2*2,activation='relu')(h_3)
h_5 = Reshape((2,2,20))(h_4)


x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(40, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(80,  (3, 3), activation='tanh',padding='same',kernel_initializer='normal')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='tanh', padding='same')(x)

EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=0, mode='auto')
checkpoint = keras.callbacks.ModelCheckpoint('model_save_classification_BN.h5',monitor = 'val_loss',verbose = 1,save_best_only = True)


def vae_loss(x, decoded):  
    xent_loss = K.sum(K.sum(objectives.mse(x ,decoded),axis=-1),axis=-1)
    #wasserstein_loss = K.sum(K.square(z_mean), axis=-1)
    #kl_loss_2 = K.sum(K.abs(1- K.exp(z_log_var)), axis=-1)
    return 1*xent_loss 

def ae_loss(x, decoded):  
    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
    return xent_loss

if USE == 'autoencoder':
    autoencoder = Model(inputs=input_img, outputs=decoded)
    autoencoder.compile(optimizer='rmsprop', loss=ae_loss)
if USE == 'vae':
    vae = Model(inputs=input_img, outputs=decoded) 
    vae.compile(optimizer='rmsprop', loss=vae_loss)

# %%
vae.fit(train_data[:12000], train_data[:12000],
        shuffle=True,
        epochs=nb_epoch,
        batch_size=batch_size,  
        validation_data=(train_data[12000:14100],train_data[12000:14100]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 12000 samples, validate on 2100 samples
# Epoch 1/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 250.0381Epoch 00000: val_loss improved from inf to 198.32115, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 24s - loss: 249.6279 - val_loss: 198.3212
# Epoch 2/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 181.3592Epoch 00001: val_loss improved from 198.32115 to 191.60832, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: 181.7785 - val_loss: 191.6083
# Epoch 3/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 171.7762Epoch 00002: val_loss improved from 191.60832 to 181.76447, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: 171.8261 - val_loss: 181.7645
# Epoch 4/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 166.7401Epoch 00003: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: 166.8505 - val_loss: 185.2032
# Epoch 5/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 163.7004- EEpoch 00004: val_loss improved from 181.76447 to 178.18996, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: 164.1499 - val_loss: 178.1900
# Epoch 6/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 162.5066Epoch 00005: val_loss improved from 178.18996 to 169.83021, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 20s - loss: 162.5158 - val_loss: 169.8302
# Epoch 7/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 160.5149Epoch 00006: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: 160.1106 - val_loss: 171.8597
# Epoch 8/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 158.7030Epoch 00007: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: 158.7709 - val_loss: 177.3389
# Epoch 9/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 157.2633Epoch 00008: val_loss improved from 169.83021 to 168.13440, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 21s - loss: 157.3746 - val_loss: 168.1344
# Epoch 10/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 156.3405Epoch 00009: val_loss improved from 168.13440 to 166.59334, saving model to model_save_classification_BN.h5
# 12000/12000 [==============================] - 22s - loss: 156.6729 - val_loss: 166.5933
# Epoch 11/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 155.0933Epoch 00010: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: 154.9272 - val_loss: 169.3793
# Epoch 12/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 153.9801Epoch 00011: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: 153.7872 - val_loss: 171.4639
# Epoch 13/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 153.9434Epoch 00012: val_loss did not improve
# 12000/12000 [==============================] - 21s - loss: 153.7803 - val_loss: 169.9508
# Epoch 14/50
# 11900/12000 [============================>.] - ETA: 0s - loss: 152.5840Epoch 00013: val_loss did not improve
# 12000/12000 [==============================] - 20s - loss: 152.6839 - val_loss: 167.1221

# %%
# encode and decode some digits
# note that we take them from the *test* set
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

#encoded_imgs = encoder.predict(x_test)

decoded_imgs = vae.predict(train_data[8000:9500],batch_size=100)

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(1,n):
    # display original
    ax = plt.subplot(2,n,i)
    plt.imshow((train_data[8000:9500][i][:,:,0]))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n ,i + n)
    plt.imshow((decoded_imgs[i][:,:,0]))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
lower_lim = 0
upper_lim = 14000

label_value = np.zeros(len(train_label))
for i in range(len(label_value)):
    label_value[i] =np.argmax(train_label[i])

vis = Model(input_img, z_mean)

# display a 2D plot of the digit classes in the latent space  
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)

x_vis_1 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_1[label_value[lower_lim:upper_lim]<1]=0

x_vis_2 = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)  
x_vis_2[label_value[lower_lim:upper_lim]==1]=0

plt.figure(figsize=(20, 5))

ax = plt.subplot(1,3,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,2)
plt.scatter( x_vis_1[:, 0] ,x_vis_1[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,3,3)
plt.scatter( x_vis_2[:, 0] ,x_vis_2[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
lower_lim = 6000
upper_lim = 7000


vis = Model(input_img, z_mean)
# display a 2D plot of the digit classes in the latent space
x_vis = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
n_neighbors = 10
n_components = 1
isomap = manifold.Isomap(n_neighbors, n_components)
hid_pred = vis.predict(train_data[lower_lim:upper_lim], batch_size=batch_size)
Y_pred = isomap.fit_transform(hid_pred)


plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()


tsne = manifold.TSNE(n_components=n_components, init='pca', random_state=2)
Y_pred = tsne.fit_transform(hid_pred)
plt.figure(figsize=(12, 5))

ax = plt.subplot(1,2,1)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=label_value[lower_lim:upper_lim])
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
ax = plt.subplot(1,2,2)
plt.scatter( x_vis[:, 0] ,x_vis[:, 1],c=Y_pred)
plt.colorbar()
plt.xlabel("Hidden variable 1")
plt.ylabel("Hidden variable 2")
plt.show()

# %%
#Y_pred = -Y_pred
thr_min = -40
thr_max = 40
test_accuracy = 0.01
test_range = int((thr_max - thr_min)/test_accuracy)
print(test_range)
FP = []
TP = []
TN = []
FN = []
TA = np.ones((Y_pred.shape[0],))
TA[Class[lower_lim:upper_lim] ==0 ] = 0
TA[Class[lower_lim:upper_lim] ==2 ] = 0

for i in range(test_range):
    FP_temp = np.zeros((Y_pred.shape[0]))
    TP_temp = np.zeros((Y_pred.shape[0]))
    TN_temp = np.zeros((Y_pred.shape[0]))
    FN_temp = np.zeros((Y_pred.shape[0]))
    LA = np.zeros((Y_pred.shape[0],))
    thr_now = thr_min+ i*test_accuracy
    LA[Y_pred[:,0] > thr_now] = 1
    for j in range(Y_pred.shape[0]):
        if LA[j]==0:
            if TA[j]==1:
                FN_temp[j] = 1
            else:
                TN_temp[j] = 1
        else:
            if TA[j] == 1:
                TP_temp[j] = 1
            else:
                FP_temp[j] = 1
    FP.append(FP_temp)
    TP.append(TP_temp)
    TN.append(TN_temp)
    FN.append(FN_temp)
    
TPR = np.zeros((test_range,))
FPR = np.zeros((test_range,))
TPR = np.sum(TP,axis=-1)/(np.sum(TP,axis=-1)+np.sum(FN,axis=-1))
FPR = np.sum(FP,axis=-1)/(np.sum(FP,axis=-1)+np.sum(TN,axis=-1))

plt.scatter(FPR,TPR,c=[i for i in range(test_range)])

plt.colorbar()
plt.scatter(FPR[np.argmin((TPR-1)**2 + FPR**2)],TPR[np.argmin((TPR-1)**2 + FPR**2)],c=0,cmap='OrRd_r')
plt.xlabel('FPR')
plt.ylabel('TPR')
#argmax, OrRed

print("AUC:",metrics.auc(FPR, TPR))
# Out:
# 8000
# AUC: 0.753815266995
